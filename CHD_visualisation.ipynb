# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./CHDdata.csv')

# %%
df
# Out:
#      sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  age  \
# 0    160    12.00   5.73      23.11  Present     49    25.30    97.20   52
# 1    144     0.01   4.41      28.61   Absent     55    28.87     2.06   63
# 2    118     0.08   3.48      32.28  Present     52    29.14     3.81   46
# 3    170     7.50   6.41      38.03  Present     51    31.99    24.26   58
# 4    134    13.60   3.50      27.78  Present     60    25.99    57.34   49
# ..   ...      ...    ...        ...      ...    ...      ...      ...  ...
# 457  214     0.40   5.98      31.72   Absent     64    28.45     0.00   58
# 458  182     4.20   4.41      32.10   Absent     52    28.61    18.72   52
# 459  108     3.00   1.59      15.23   Absent     40    20.09    26.64   55
# 460  118     5.40  11.61      30.79   Absent     64    27.35    23.97   40
# 461  132     0.00   4.82      33.41  Present     62    14.70     0.00   46
#
#      chd
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
# ...

# %%
df['Category'] = df["chd"].astype("category")

# %%
df.plot(x="sbp", y="tobacco", kind="scatter", c="Category", cmap="Set3")
# Out:
# <AxesSubplot: xlabel='sbp', ylabel='tobacco'>

# %%
df.plot(x="age", y="tobacco", kind="scatter", c="Category", cmap="Set3")
# Out:
# <AxesSubplot: xlabel='age', ylabel='tobacco'>

# %%
df.plot(x="sbp", y="ldl", kind="scatter", c="Category", cmap="Set3")
# Out:
# <AxesSubplot: xlabel='sbp', ylabel='ldl'>

# %%
df.plot(x="alcohol", y="age", kind="scatter", c="Category", cmap="Set3")
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='age'>

# %%
df.plot(x="obesity", y="adiposity", kind="scatter", c="Category", cmap="Set3")
# Out:
# <AxesSubplot: xlabel='obesity', ylabel='adiposity'>
